# %% [markdown]
# # Sample Notebook
#
# A notebook with a chart output that must keep its layout in PDF.

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[1,4,9])
plt.show()

# %%
print("done")
# Out:
# done
